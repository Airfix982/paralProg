# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./csv/performance.csv')
dataOMP = pd.read_csv('./csv/performance_openMP.csv')
print(dataOMP)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = pd.read_csv('performance.csv')
#       2 dataOMP = pd.read_csv('performance_openMP.csv')
#       3 print(dataOMP)
#
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['MatrixSize'], data[' AverageDuration'], marker='o')
plt.title('Average Duration vs Matrix Size')
plt.xlabel('Matrix Size')
plt.ylabel('Average Duration (ms)')
plt.grid(True)
plt.savefig('./png/avg_dur_not_paral.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='MatrixSize', y=' AverageOperations', marker='o', color='orange')
plt.title('Average Number of Operations for Matrix Multiplication')
plt.xlabel('Matrix Size')
plt.ylabel('Average Operations')
plt.grid(True)
plt.savefig('./png/avg_oper_not_paral.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 sns.lineplot(data=data, x='MatrixSize', y=' AverageOperations', marker='o', color='orange')
#       3 plt.title('Average Number of Operations for Matrix Multiplication')
#       4 plt.xlabel('Matrix Size')
#
# NameError: name 'sns' is not defined

# %%
plt.figure(figsize=(10, 6))
plt.plot(dataOMP['MatrixSize'], dataOMP[' AverageDuration'], marker='o')
plt.title('Average Duration vs Matrix Size')
plt.xlabel('Matrix Size')
plt.ylabel('Average Duration (ms)')
plt.grid(True)
plt.savefig('./png/avg_dur_OPM.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=dataOMP, x='MatrixSize', y=' AverageOperations', marker='o', color='orange')
plt.title('Average Number of Operations for Matrix Multiplication')
plt.xlabel('Matrix Size')
plt.ylabel('Average Operations')
plt.grid(True)
plt.savefig('./png/avg_oper_OMP.png')
plt.show()
