# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('performance.csv')
print(data)
# Out:
#     MatrixSize   AverageDuration   AverageOperations
# 0           50               0.6                2500
# 1          100               7.8               10000
# 2          150              28.4               22500
# 3          200              61.6               40000
# 4          250             150.2               62500
# 5          300             201.4               90000
# 6          350             303.6              122500
# 7          400             460.6              160000
# 8          450             682.2              202500
# 9          500            1032.6              250000
# 10         550            1549.6              302500
# 11         600            2337.2              360000
# 12         650            3320.4              422500
# 13         700            4234.8              490000
# 14         750            5162.2              562500
# 15         800            7374.6              640000

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['MatrixSize'], data[' AverageDuration'], marker='o')
plt.title('Average Duration vs Matrix Size')
plt.xlabel('Matrix Size')
plt.ylabel('Average Duration (ms)')
plt.grid(True)
plt.savefig('avg_dur_not_paral.png')  # Сохраняем график в файл
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=data, x='MatrixSize', y=' AverageOperations', marker='o', color='orange')
plt.title('Average Number of Operations for Matrix Multiplication')
plt.xlabel('Matrix Size')
plt.ylabel('Average Operations')
plt.grid(True)
plt.savefig('avg_oper_not_paral.png')
plt.show()
